# %% [markdown]
# ## Задание 6
#
# Обучить сиамскую сеть для верификации лиц на датасете LFW
# Библиотеки: [Python, Tensorflow]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
import tarfile
import pathlib
import tensorflow as tf

# %%
if 1:
    dataset_url = "http://vis-www.cs.umass.edu/lfw/lfw.tgz"

    data_dir = tf.keras.utils.get_file(origin=dataset_url,
                                    fname='lfw',
                                    untar=True )

    data_dir = pathlib.Path(data_dir)
else: 
    data_dir = pathlib.Path('lfw')
# Out:
# Downloading data from http://vis-www.cs.umass.edu/lfw/lfw.tgz
# 180568064/180566744 [==============================] - 2s 0us/step
# 180576256/180566744 [==============================] - 2s 0us/step

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 13233

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 13233 files belonging to 5749 classes.
# Using 10587 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 13233 files belonging to 5749 classes.
# Using 2646 files for validation.

# %%
class_names = train_ds.class_names
print(class_names[:10])
# Out:
# ['AJ_Cook', 'AJ_Lamas', 'Aaron_Eckhart', 'Aaron_Guiel', 'Aaron_Patterson', 'Aaron_Peirsol', 'Aaron_Pena', 'Aaron_Sorkin', 'Aaron_Tippin', 'Abba_Eban']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(8):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(f'{class_names[labels[i]]}/{labels[i]}')
    plt.axis("off")

# %% [markdown]
# ### Создание модели CNN

# %%
EMB_SIZE = 64

model = tf.keras.models.Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255.0),
    tf.keras.layers.Conv2D(32, (5, 5), padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), (2, 2)),
    tf.keras.layers.Conv2D(64, (5, 5), padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), (2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(EMB_SIZE, activation=None),
])

# %% [markdown]
# ### Contrastive Loss

# %%
MARGIN = 10.0

def contastive_loss(embs, labels):
    try:
        bs = embs.shape[0]
        embs1 = embs[:bs//2, :]
        embs2 = embs[bs//2:, :]
        labels1 = labels[:bs//2]
        labels2 = labels[bs//2:]

        d2 = tf.reduce_sum(tf.square(embs1 - embs2), axis=1)
        d =  tf.sqrt(d2)
        z = tf.cast(labels1 == labels2, tf.float32)
    except Exception as ex:
        print('>',embs1)
        print('>',embs2)
        print(ex)
    return tf.reduce_mean(z * d2 + (1-z) * tf.maximum(0, MARGIN - d)**2)

# %% [markdown]
# ### Подготовка к обучению

# %%
BATCH_SIZE = 32
NUM_EPOCHS = 3

LEARNING_RATE = 0.001
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)

# %% [markdown]
# ### Обучение модели

# %%
# %%time
for epoch in range(NUM_EPOCHS):
    for iteration, (images, labels) in enumerate(train_ds):
        if(len(labels)%2 > 0): # на последней операции в эпохе возникает ошибка.  из-за того что к-во элементов в батче не четное. 
                labels = labels[:-1]
                images = images[:-1]
        # Forward
        with tf.GradientTape() as tape:
            embs = model(images)
            loss_value = contastive_loss(embs, labels)
            
        # Backward
        grads = tape.gradient(loss_value, model.variables)
        optimizer.apply_gradients(zip(grads, model.variables))

        if iteration % 100 == 0:
            print('[{}/{}] Loss: {}'.format(epoch,iteration, loss_value.numpy()))
# Out:
# [0/0] Loss: 84.6019515991211
# [0/100] Loss: 0.0
# [0/200] Loss: 0.0
# [0/300] Loss: 0.3805219829082489
# [1/0] Loss: 0.0
# [1/100] Loss: 0.0
# [1/200] Loss: 0.0
# [1/300] Loss: 8.880224777385592e-05
# [2/0] Loss: 0.364097535610199
# [2/100] Loss: 0.5479220151901245
# [2/200] Loss: 0.33113741874694824
# [2/300] Loss: 0.012865791097283363
# CPU times: user 1min 22s, sys: 4.61 s, total: 1min 26s
# Wall time: 1min 20s

# %% [markdown]
# ### Получение эмбеддингов для тестовой выборки

# %%
images, labels = next(iter(val_ds))

# %%
# %%time

test_imgs=[]
test_labels = []
test_embs = []
for iteration, (images, labels) in enumerate(val_ds):
    for label in labels.numpy():
        test_labels.append(label) 
    embs = model(images)
    for emb in embs.numpy():
        test_embs.append(emb)
test_labels = np.array(test_labels)
test_embs = np.array(test_embs)
# Out:
# CPU times: user 4.88 s, sys: 299 ms, total: 5.18 s
# Wall time: 2.94 s

# %%
test_lbl_count = {}
for i in test_labels:
    name = class_names[i]
    if name in test_lbl_count:
        test_lbl_count[name] += 1
    else:
        test_lbl_count[name] = 1

# %%
test_lbl_count = list(test_lbl_count.items())
test_lbl_count = sorted(test_lbl_count, key=lambda x:x[1], reverse=True)
top_10 = test_lbl_count[:10]
top_10
# Out:
# [('George_W_Bush', 121),
#  ('Colin_Powell', 50),
#  ('Tony_Blair', 32),
#  ('Donald_Rumsfeld', 29),
#  ('Gerhard_Schroeder', 23),
#  ('Junichiro_Koizumi', 19),
#  ('Hugo_Chavez', 14),
#  ('Jean_Chretien', 13),
#  ('Serena_Williams', 12),
#  ('Lleyton_Hewitt', 12)]

# %% [markdown]
# ### Тестирование на новых данных

# %%
images, labels = next(iter(val_ds))

# %%
fig, ax = plt.subplots(1,3,figsize=(12,4))
for i in range(3):
    ax[i].imshow(images[i].numpy().astype("uint8"))
    ax[i].set_title(class_names[labels[i].numpy()])
plt.show()

# %% [markdown]
# ### Получение эмбеддингов для новых данных

# %%
new_embs = model(np.stack(images[:3], axis=0))

# %% [markdown]
# ### Вычисление расстояний между эмбеддингами

# %%
def diff(e1, e2):
    return np.sum((e1 - e2)**2) ** 0.5

emb1 = new_embs[0,:]
emb2 = new_embs[1,:]
emb3 = new_embs[2,:]

print('A1 <-> A2: ', diff(emb1, emb2))
print('A2 <-> B1: ', diff(emb2, emb3))
print('A1 <-> B1: ', diff(emb1, emb3))
# Out:
# A1 <-> A2:  16.032602472493842
# A2 <-> B1:  15.02973686104666
# A1 <-> B1:  12.370882216181698
